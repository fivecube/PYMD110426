# %% [markdown]
# # Basic syntax and data types

# %%
1. python uses indentation
2. you write comments with #
    comments are simple lines which you want other people to read when they are reading your code.
3. Python is an interpreted language:- line by line
4. Everything in python is an object
5. variable naming:- It can only contain alphabets, numbers and underscore(_)
                     You can not start a variable name with number

# %%
if (x == 2) { 
                println('hwllo world in anohter pl')
            }

# %%
if x == 2:
    print('Hello world!')
print('something else')

# %%
common data types:-
age = 25 # int
price = 45.66 # float
name = "Rohan" # string
sentence = "The quick brown fox jumps over a lazy dog" # string
is_active = True # boolean
do_payment = False # boolean
x = None #null

# %%
# Variables and operators
variables store data

age = 25 # int
price = 45.66 # float
name = "Rohan" # string
sentence = "The quick brown fox jumps over a lazy dog" # string
is_active = True # boolean
do_payment = False # boolean
x = None #null


age, price, name, sentence, is_active, do_payment, and x are all variables.
All the things on the right hand side like 25, 45.66, "Rohan", etc are data

# %%
Operators:-

+, -, *, /, //, %, ==

# %%
age = 25 + 20 # to execute a cell, press Shift + Enter

# %%
age
# Out:
# 45

# %%
# matplotlib is a library that will help you create graphs in python and in jupyter notebook you can show them directly
# here as a finding of some research.
# bar graph, line graphs, etc

# %%
list_of_fruits = ["kiwi", "apple", "mango", "water melon"]
In most of the programming languages, counting or index position starts from 0

# %%
# Input/output operations

# %%
number = input('Write a lucky number')

print('Your lucky number is ', number)
# Out:
# Write a lucky number 56
# Your lucky number is  56

# %%
# Everything that you take as in input is by default a string.

# %%
"mohan" + " singh"
# Out:
# 'mohan singh'

# %%
4 + 5
# Out:
# 9

# %%
number = input('Write a lucky number')

new_number = number + 4


print('Your lucky number is ', new_number)
# Out:
# Write a lucky number 45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 number = input('Write a lucky number')
# ----> 3 new_number = number + 4
#       6 print('Your lucky number is ', new_number)
#
# TypeError: can only concatenate str (not "int") to str

# %%
type("lucky")
# Out:
# str

# %%
type(45)
# Out:
# int

# %%
x = 45
type(x)
# Out:
# int

# %%
y = 'brown fox'
type(y)
# Out:
# str

# %%
number = input('Write a lucky number')

print("The data type of number is", type(number))
# Out:
# Write a lucky number 45
# The data type of number is <class 'str'>

# %%
# type casting
# if you want to convert something into int and it should be a valid conversion:-

number_str = input('Write a lucky number')

print(type(number_str))

number = int(number_str)

new_number = number + 5

print(new_number)
# Out:
# Write a lucky number 45
# <class 'str'>
# 50

# %%
number = int(input('Write a lucky number')) + 5
print(number)
# Out:
# Write a lucky number 34
# 39

# %%
number = input('Write a lucky number') + 5
print(number)
# Out:
# Write a lucky number 45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 number = input('Write a lucky number') + 5
#       2 print(number)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Basic string operations

# %%
# sentence = 'happy'
# sentence2 = "new version"
# sentence3 = """ the quick brown fox! """
# sentence4 = ''' jumping jacks '''

# These are valid strings.
# If you have a big multiline string, you will use triple quotes

# %%
# string is sequence of characters

# %%
good_sentence = "the quick brown fox jumps over a lazy dog"
print(good_sentence[0])
# Out:
# t

# %%
print(good_sentence[1])
# Out:
# h

# %%
good_sentence.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER A LAZY DOG'

# %%
x = 'THE QUICK BROWN FOX JUMPS OVER A LAZY DOG'
x.lower()
# Out:
# 'the quick brown fox jumps over a lazy dog'

# %%
# concatenation

first_name = 'Avi'
last_name = "Desai"

full_name = first_name + " " + last_name
print(full_name)
# Out:
# Avi Desai

# %%
new_sentence = "I'm learning python"

# %%
len(new_sentence)
# Out:
# 19

# %%
new_sentence[1]
# Out:
# "'"

# %%
new_sentence[0]
# Out:
# 'I'

# %%
new_sentence[13]
# Out:
# 'p'

# %%
new_sentence[18]
# Out:
# 'n'

# %%
happy_$ = 45
# Out:
#   Cell In[39], line 1
#     happy_$ = 45
#           ^
# SyntaxError: invalid syntax

# %%
6mango = "mango, mango,,."
# Out:
#   Cell In[40], line 1
#     6mango = "mango, mango,,."
#      ^
# SyntaxError: invalid syntax

# %%
# slicing
new_sentence = "I'm learning python"

new_slice = new_sentence[13:18]

print(new_slice)
# Out:
# pytho

# %%
n is not present here.
Why? Because in slicing, and other similar functionalities, the end is not inclusive
Solution:- to make it inclusive add 1 to it.

# %%
# slicing
new_sentence = "I'm learning python"

new_slice = new_sentence[13:19]

print(new_slice)
# Out:
# python

# %%
# first program

list_of_fruits = ['apple', 'mango', 'banana', 'kiwi', 'water melon']

for fruit in list_of_fruits:
    if fruit[0] in ['a', 'b', 'c']:
        print(fruit.title())
# Out:
# Apple
# Banana

# %%
list_of_numbers = [10, 200, 30, 44, 23, 47, 89]

for no in list_of_numbers:
    if no%2 == 0:
        print('Even', no)
    else:
        print('Odd', no)
# Out:
# Even 10
# Even 200
# Even 30
# Even 44
# Odd 23
# Odd 47
# Odd 89

# %%
list_of_numbers = []
for n in range(0, 5):
    list_of_numbers.append(int(input('write a no')))
print(list_of_numbers)

for no in list_of_numbers:
    if no%2 == 0:
        print('Even', no)
    else:
        print('Odd', no)
# Out:
# write a no 67
# write a no 89
# write a no 22
# write a no 48
# write a no 27
# [67, 89, 22, 48, 27]
# Odd 67
# Odd 89
# Even 22
# Even 48
# Odd 27
